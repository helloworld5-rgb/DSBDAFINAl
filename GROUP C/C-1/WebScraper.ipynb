# %%
import requests
import bs4

# %%
request1=requests.get('https://www.flipkart.com/nothing-phone-3a-white-256-gb/p/itm49557c5a65f9c?pid=MOBH8G3PCBJAB8GX&lid=LSTMOBH8G3PCBJAB8GXYHLNGL&marketplace=FLIPKART&fm=productRecommendation%2Fsimilar&iid=en_ih7YWSe7_yWgS-FlEVzMBboGU5t340wy8fnOr7ZcexDOWGjsw10nya2Qw5REa2pGdZIi0BdLoUgP9zJBbNCh6Q%3D%3D&ppt=pp&ppn=pp&ssid=zh2mhz5dz40000001742801795299&otracker=pp_reco_Similar%2BProducts_2_37.productCard.PMU_HORIZONTAL_Nothing%2BPhone%2B%25283a%2529%2B%2528White%252C%2B256%2BGB%2529_-1_productRecommendation%2Fsimilar_1&otracker1=pp_reco_PINNED_productRecommendation%2Fsimilar_Similar%2BProducts_GRID_productCard_cc_2_NA_view-all&cid=-1')
request1
# Out:
# <Response [200]>

# %%
request1.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Fli
# ...

# %%
soup=bs4.BeautifulSoup(request1.text)
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
#1. Reviews

# %%
reviews=soup.find_all('div',{'class':'ZmyHeo'});
for review in reviews:
    print(review.get_text()+'\n''\n')
# Out:
# The camera is awesome, UI is simple and cleanREAD MORE
#
#
# Recently purchased nothing 3a 256gb variant and I found it value for moneyPros :-1. Design is just amazing you will love it. Gives feeling of premium phone just like you are holding an iPhone.2. Ui is very clean not bloatware and unwanted apps.3. Display is good. Bright and large display.4. performance is quite amazing I have not a gaming person but it will not let you down in day to day tasks.Cons :-1. Camera could be slightly better. It lags sharpness in low light and it overexpose ...READ MORE
#
#
# Nice look i think value for moneyREAD MORE
#
#
# GoodREAD MORE
#
#
# GreatREAD MORE
#
#
# ...

# %%
# single review

# %%
reviews=soup.find('div',{'class':'ZmyHeo'}).get_text();
reviews
# Out:
# 'The camera is awesome, UI is simple and cleanREAD MORE'

# %%
# Fetching Ratings

# %%
ratings=soup.find('div',{'class':'XQDdHH Ga3i8K'}).get_text();
print(ratings)
# Out:
# 5

# %%
ratings=soup.find_all('div',{'class':'XQDdHH Ga3i8K'});
for rating in ratings:
    print(rating.get_text()+'\n''\n')
# Out:
# 5
#
#
# 5
#
#
# 5
#
#
# 4
#
#
# 5
#
#
# 4
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 4

# %%
# Fetching customer names

# %%
ratings=soup.find_all('div',{'class':'BZMA+t'});
for rating in ratings:
    print(rating.get_text()+'\n''\n')
# Out:
# Q:Fingerprint kha par haiA:Indisplay fingerprintBishal DasCertified Buyer11025Report Abuse
#
#
# Q:Screen protector is provided or not ?A:No, a plastic film is stickered on deviceBishal DasCertified Buyer6127Report Abuse
#
#
# Q:How many expendable storageA:It doesn't have expendable storage. It consists of two sim slot.AnonymousCertified Buyer2611Report Abuse
#
#
# Q:Nothing phone 3a OIS camera or notA:Yes the main 50 MP camera contains OISAnonymousCertified Buyer40Report Abuse
#
#
# Q:Cani use a vivo 45W adapter for charging this phone with the help of Type A to C converterA:Yes you can useBishal DasCertified Buyer5019Report Abuse

# %%
ratings=soup.find_all('div',{'class':'JxAXcP'});
for rating in ratings:
    print(rating.get_text()+'\n''\n')
# Out:
# A:Indisplay fingerprint
#
#
# A:No, a plastic film is stickered on device
#
#
# A:It doesn't have expendable storage. It consists of two sim slot.
#
#
# A:Yes the main 50 MP camera contains OIS
#
#
# A:Yes you can use
